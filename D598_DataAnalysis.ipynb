# %% [markdown]
# # D598 TASK 2 Project

# %% [markdown]
# ## Introduction
#
# <p>The dataset to be analyzed in this project is "D598 Data Set.xlsx." The data is about the financial performance of 150 U.S. companies across multiple industries based on the most recent quarter. </p>

# %% [markdown]
# ## Importing Pandas and NumPy libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <p>Importing both Pandas and NumPy libraries are necessary for data manipulation. NumPy works well with creating N-dimension data objects, while Pandas "is renowned for data wrangling and its ability to handle large datasets" (Ginsberg, 2024, par. 3). </p>

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_excel('C:/Users/jcaye/Downloads/D598 Data Set.xlsx')
df
# Out:
#      Business ID Business State  Total Long-term Debt  Total Equity  \
# 0       41872013       Kentucky            16889000.0  1.804600e+07
# 1       76232013           Iowa             6252000.0  1.829362e+07
# 2      160992013          Texas            19200000.0  1.778580e+08
# 3      197452013       Delaware           117592000.0  2.787730e+08
# 4      241042013       Illinois             4408000.0  5.206400e+07
# ..           ...            ...                   ...           ...
# 145  14733342013     California             6602000.0  3.872871e+07
# 146  14871012013       Maryland            56000000.0  2.813310e+08
# 147  14889172013      MInnesota             1332000.0  1.392683e+07
# 148  15456542013         Hawaii           605500000.0  1.173200e+09
# 149  15528002013      MInnesota            92807000.0  7.873600e+07
#
#      Debt to Equity  Total Liabilities  Total Revenue  Profit Margin
# 0          0.935886       2.598600e+07      136753000       0.023663
# ...

# %% [markdown]
# <p>The data set has 8 columns and 150 rows</p>

# %%
df.describe()
# Out:
#         Business ID  Total Long-term Debt  Total Equity  Debt to Equity  \
# count  1.500000e+02          1.500000e+02  1.500000e+02      150.000000
# mean   8.238634e+09          1.312688e+08  1.719787e+08        0.662109
# std    4.461905e+09          4.198194e+08  4.004449e+08        2.129141
# min    4.187201e+07          3.000000e+03 -1.112970e+08       -4.283552
# 25%    7.185677e+09          2.761500e+06  1.229411e+07        0.100133
# 50%    8.937757e+09          9.749500e+06  3.563068e+07        0.314113
# 75%    1.103050e+10          7.772125e+07  1.294800e+08        0.771130
# max    1.552800e+10          3.183823e+09  2.858019e+09       19.680109
#
#        Total Liabilities  Total Revenue  Profit Margin
# count       1.500000e+02   1.500000e+02     150.000000
# mean        2.764051e+08   3.397338e+08      -0.557845
# std         7.527120e+08   8.271448e+08      10.006228
# min         7.530000e+05   1.595830e+05    -122.221145
# ...

# %% [markdown]
# <p> Here are the basic statistics for each column. </p>

# %%
df.dtypes
# Out:
# Business ID               int64
# Business State           object
# Total Long-term Debt    float64
# Total Equity            float64
# Debt to Equity          float64
# Total Liabilities       float64
# Total Revenue             int64
# Profit Margin           float64
# dtype: object

# %% [markdown]
# <p>These are datatypes for all the columns in the dataset</p>

# %%
df.isnull().sum()
# Out:
# Business ID             0
# Business State          0
# Total Long-term Debt    0
# Total Equity            0
# Debt to Equity          0
# Total Liabilities       0
# Total Revenue           0
# Profit Margin           0
# dtype: int64

# %% [markdown]
# <p>There are no null values in the dataset</p>

# %% [markdown]
# ## Checking for duplicate rows

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Business ID, Business State, Total Long-term Debt, Total Equity, Debt to Equity, Total Liabilities, Total Revenue, Profit Margin]
# Index: []

# %% [markdown]
# <p> Not a single row was returned, which means the data does not contain any duplicate rows. </p>

# %% [markdown]
# ## Grouping IDs by state and calculate descriptive statistics for all numeric columns

# %%
df.groupby('Business State').agg(['mean', 'median', 'min', 'max'])
# Out:
#                   Business ID                                          \
#                          mean        median          min          max
# Business State
# Alabama          1.599117e+09  1.599117e+09    422282013   2775952013
# Arizona          9.445082e+09  9.445082e+09   9445082013   9445082013
# Arkansas         8.411162e+09  8.411162e+09   7982872013   8839452013
# California       1.063053e+10  1.034300e+10   7192742013  14733342013
# Colorado         9.966963e+09  1.008177e+10   3194582013  14214612013
# Connecticut      1.123316e+10  1.123316e+10  11233162013  11233162013
# Delaware         6.936917e+09  8.686742e+09    197452013  10176732013
# Florida          7.520922e+09  8.670152e+09   3507372013   9236012013
# Hawaii           1.545654e+10  1.545654e+10  15456542013  15456542013
# Idaho            1.181126e+10  1.181126e+10  10382772013  13239742013
# Illinois         5.950345e+09  7.590952e+09    241042013  10421872013
# ...

# %% [markdown]
# <p>After grouping business IDs by state and calculated descriptive statistics for each numerical columns, this is the result. It provided the mean, median, min & max for all numerical columns for each state.</p>

# %% [markdown]
# ## Creating a new data frame to store the grouped data above

# %%
df_grouped = df.groupby('Business State').agg(['mean', 'median', 'min', 'max'])

# %% [markdown]
# <p>The new data frame 'df_grouped' contains data that has been grouped by state, and descriptive statistics for all numerical columns.</p>

# %% [markdown]
# ## Filtering data to return businesses with negative debt to equity ratios

# %%
df[df['Debt to Equity'] < 0]
# Out:
#      Business ID Business State  Total Long-term Debt  Total Equity  \
# 18     934562013           Ohio           263880000.0  -111297000.0
# 57    8343652013     Washington            10603000.0   -13271658.0
# 87    9323722013     California            21560000.0   -15691000.0
# 109  10919832013           Utah             2010000.0    -3602481.0
# 117  11245242013     California              556000.0    -2063203.0
# 142  14535932013        Montana            16459000.0    -3842372.0
# 143  14639722013       New York              187000.0   -13037879.0
#
#      Debt to Equity  Total Liabilities  Total Revenue  Profit Margin
# 18        -2.370953        592174000.0      719783000       0.320697
# 57        -0.798921         16625000.0        8949401       0.448119
# 87        -1.374036         30048000.0       37782000       0.505955
# 109       -0.557949          6302000.0       17757388       0.732562
# 117       -0.269484          3819000.0        1100539      -0.084923
# ...

# %% [markdown]
# <p>These are the businesses that have negative debt to equity ratios. </p>

# %% [markdown]
# ## Calculating debt to income ratios

# %%
# Calculate Debt-to-Income Ratio
df['Debt to Income Ratio'] = df['Total Long-term Debt'] / df['Total Revenue']

# %%
df
# Out:
#      Business ID Business State  Total Long-term Debt  Total Equity  \
# 0       41872013       Kentucky            16889000.0  1.804600e+07
# 1       76232013           Iowa             6252000.0  1.829362e+07
# 2      160992013          Texas            19200000.0  1.778580e+08
# 3      197452013       Delaware           117592000.0  2.787730e+08
# 4      241042013       Illinois             4408000.0  5.206400e+07
# ..           ...            ...                   ...           ...
# 145  14733342013     California             6602000.0  3.872871e+07
# 146  14871012013       Maryland            56000000.0  2.813310e+08
# 147  14889172013      MInnesota             1332000.0  1.392683e+07
# 148  15456542013         Hawaii           605500000.0  1.173200e+09
# 149  15528002013      MInnesota            92807000.0  7.873600e+07
#
#      Debt to Equity  Total Liabilities  Total Revenue  Profit Margin  \
# 0          0.935886       2.598600e+07      136753000       0.023663
# ...

# %% [markdown]
# <p>These are the debt to income ratio for all businesses. Debt to income ratio was calculated by dividing total long-term debt by total revenue. An additional column was added to the main data frame.</p>

# %% [markdown]
# ## Creating a new data frame that only includes the debt to income ratios for all businesses

# %%
df2 = df[['Business ID','Debt to Income Ratio']]
df2
# Out:
#      Business ID  Debt to Income Ratio
# 0       41872013              0.123500
# 1       76232013              0.182665
# 2      160992013              0.049974
# 3      197452013              0.264664
# 4      241042013              0.036268
# ..           ...                   ...
# 145  14733342013              0.084256
# 146  14871012013              0.187459
# 147  14889172013              0.088186
# 148  15456542013              1.657996
# 149  15528002013              0.404275
#
# [150 rows x 2 columns]

# %% [markdown]
# <p> This is a new data frame that only contains two columns: business ID and debt to income ratio. The column, debt to income ratio, is a newly created column from the previous step. This data frame will be merged with the original data frame in the next step.</p>

# %% [markdown]
# ## Concatenating debt-to-income ratio data frame 'df2' with the original data frame 'df'

# %%
concatenated_df = pd.concat([df.drop(columns='Debt to Income Ratio'), df2['Debt to Income Ratio']], axis=1)

# %%
concatenated_df
# Out:
#      Business ID Business State  Total Long-term Debt  Total Equity  \
# 0       41872013       Kentucky            16889000.0  1.804600e+07
# 1       76232013           Iowa             6252000.0  1.829362e+07
# 2      160992013          Texas            19200000.0  1.778580e+08
# 3      197452013       Delaware           117592000.0  2.787730e+08
# 4      241042013       Illinois             4408000.0  5.206400e+07
# ..           ...            ...                   ...           ...
# 145  14733342013     California             6602000.0  3.872871e+07
# 146  14871012013       Maryland            56000000.0  2.813310e+08
# 147  14889172013      MInnesota             1332000.0  1.392683e+07
# 148  15456542013         Hawaii           605500000.0  1.173200e+09
# 149  15528002013      MInnesota            92807000.0  7.873600e+07
#
#      Debt to Equity  Total Liabilities  Total Revenue  Profit Margin  \
# 0          0.935886       2.598600e+07      136753000       0.023663
# ...

# %% [markdown]
# <p>Here we concatenated the newly created data frame 'df2' that contains the debt to income ratio for businesses with the original data frame 'df.' The final data frame now contains the debt to income ratio. We had to drop the debt to income ratio column in the original data frame to show that we can merge two different data frames using the concat function.</p>

# %% [markdown]
# ## References

# %% [markdown]
# <pre>Ginsberg, C. (2024, June 6). <i>Pandas vs. numpy: Which Python Library is better for data analytics?</i>. Classes Near Me Blog.
#                 https://www.nobledesktop.com/classes-near-me/blog/pandas-vs-numpy-for-data-analytics </pre>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize=(10, 6))

sns.regplot(x=df['Total Liabilities'], y=df['Total Revenue'], scatter=True, color='orange', line_kws={"color": "orange"})
plt.title('Total Liabilities vs Total Revenue')
plt.xlabel('Total Liabilities')
plt.ylabel('Total Revenue')
plt.grid(True)

plt.show()

# %%
sort_df = df.sort_values(by='Total Revenue', ascending=False)
plt.figure(figsize=(10, 6))

plt.bar(sort_df['Business State'], sort_df['Total Revenue'], color='orange')
plt.title('Total Revenue by Business State')
plt.xlabel('Business State')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90, fontsize=10) 
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 8))

plt.hist(df['Debt to Income Ratio'], bins=4, color='orange', alpha=0.8)
plt.title('Distribution of Debt to Income Ratio')
plt.xlabel('Debt to Income Ratio')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.8)

plt.show()

# %%
grouped_data = df.groupby('Business State')['Total Liabilities'].sum()
top_5 = grouped_data.sort_values(ascending=False).head(5)
plt.figure(figsize=(8, 8))

plt.pie(top_5, labels=top_5.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 States by Total Liabilities')
plt.show()
